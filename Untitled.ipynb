# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("imdb_top500_movies_list.csv")
print(df)
# Out:
#         budget      id original_language  \
# 0            0   89861                en
# 1            0   78373                en
# 2            1  361505                en
# 3            0   40963                en
# 4            0  346081                en
# 5            0   69848                en
# 6     25000000     278                en
# 7     10500000   88641                en
# 8            0   43867                en
# 9      6000000     238                en
# 10    63000000     550                en
# 11    22000000     424                en
# 12    13000000     240                en
# 13     8000000     680                en
# 14     3300000  244786                en
# 15       50000  322745                en
# 16   185000000     155                en
# 17    60000000     497                en
# 18    55000000      13                en
# 19    30000000     311                en
# 20    25000000     769                en
# 21    18000000    1891                en
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 497 entries, 0 to 496
# Data columns (total 13 columns):
# budget               497 non-null int64
# id                   497 non-null int64
# original_language    497 non-null object
# original_title       497 non-null object
# popularity           497 non-null float64
# release_date         497 non-null object
# revenue              497 non-null int64
# runtime              496 non-null float64
# status               497 non-null object
# tagline              428 non-null object
# title                497 non-null object
# vote_average         497 non-null float64
# vote_count           497 non-null int64
# dtypes: float64(3), int64(4), object(6)
# memory usage: 50.6+ KB

# %%
df['release_date'].head()
# Out:
# 0    6/12/1998
# 1     5/1/1998
# 2     7/7/2015
# 3     1/1/2006
# 4    6/26/2015
# Name: release_date, dtype: object

# %%
df['release_date'].to_datetime()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-ea053e4002f9> in <module>
# ----> 1 df['release_date'].to_datetime()
#
# ~/.local/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'to_datetime'

# %%
df['release_date'] = pd.to_datetime(df['release_date'], format='%Y/%d/%m','coerce')
# Out:
#   File "<ipython-input-20-deb173896d41>", line 1
#     df['release_date'] = pd.to_datetime(df['release_date'], format='%Y/%d/%m','coerce')
#                                                                              ^
# SyntaxError: positional argument follows keyword argument

# %%
print(df.info)
# Out:
# <bound method DataFrame.info of         budget      id original_language  \
# 0            0   89861                en
# 1            0   78373                en
# 2            1  361505                en
# 3            0   40963                en
# 4            0  346081                en
# 5            0   69848                en
# 6     25000000     278                en
# 7     10500000   88641                en
# 8            0   43867                en
# 9      6000000     238                en
# 10    63000000     550                en
# 11    22000000     424                en
# 12    13000000     240                en
# 13     8000000     680                en
# 14     3300000  244786                en
# 15       50000  322745                en
# 16   185000000     155                en
# 17    60000000     497                en
# 18    55000000      13                en
# 19    30000000     311                en
# 20    25000000     769                en
# ...

# %%
df.to_csv(r'movie_dataset.csv')

# %%
df1 = pd.read_csv('movie_dataset.csv', index_col = False)
df1.head()
# Out:
#    Unnamed: 0  budget      id original_language         original_title  \
# 0           0       0   89861                en       Stiff Upper Lips
# 1           1       0   78373                en  Dancer; Texas Pop. 81
# 2           2       1  361505                en  Me You and Five Bucks
# 3           3       0   40963                en         Little Big Top
# 4           4       0  346081                en              Sardaarji
#
#    popularity release_date  revenue  runtime    status  \
# 0    0.356495    6/12/1998        0     99.0  Released
# 1    0.376662     5/1/1998   565592     97.0  Released
# 2    0.094105     7/7/2015        0     90.0  Released
# 3    0.092100     1/1/2006        0      0.0   Rumored
# 4    0.296981    6/26/2015        0      0.0  Released
#
#                                         tagline                  title  \
# 0                                           NaN       Stiff Upper Lips
# ...

# %%
#df.drop('Unnamed:', axis=0, inplace=True)
df = df.drop('Unnamed:0', 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-303f59ce198e> in <module>
#       1 #df.drop('Unnamed:', axis=0, inplace=True)
# ----> 2 df = df.drop('Unnamed:0', 1)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~/.local/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# ...

# %%
df['release_date'].min()
# Out:
# '1/1/1997'

# %%
df1
# Out:
#      Unnamed: 0     budget      id original_language  \
# 0             0          0   89861                en
# 1             1          0   78373                en
# 2             2          1  361505                en
# 3             3          0   40963                en
# 4             4          0  346081                en
# 5             5          0   69848                en
# 6             6   25000000     278                en
# 7             7   10500000   88641                en
# 8             8          0   43867                en
# 9             9    6000000     238                en
# 10           10   63000000     550                en
# 11           11   22000000     424                en
# 12           12   13000000     240                en
# 13           13    8000000     680                en
# 14           14    3300000  244786                en
# 15           15      50000  322745                en
# 16           16  185000000     155                en
# ...

# %%
pd.Index()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-9d817241971f> in <module>
# ----> 1 pd.Index()
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/base.py in __new__(cls, data, dtype, copy, name, fastpath, tupleize_cols, **kwargs)
#     466                          **kwargs)
#     467         elif data is None or is_scalar(data):
# --> 468             cls._scalar_data_error(data)
#     469         else:
#     470             if tupleize_cols and is_list_like(data):
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/base.py in _scalar_data_error(cls, data)
#    3797         raise TypeError('{0}(...) must be called with a collection of some '
#    3798                         'kind, {1} was passed'.format(cls.__name__,
# -> 3799                                                       repr(data)))
#    3800
#    3801     @classmethod
#
# ...

# %%
export_csv = df.to_csv (r'movie_dataset.csv', index = None, header=True) #Don't forget to add '.csv' at the end of the path
